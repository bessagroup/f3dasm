# %%
from typing import Callable
import numpy as np
import pytest
from f3dasm.src.space import (
    ContinuousSpace,
    DiscreteSpace,
    CategoricalSpace,
    SpaceInterface,
)
from hypothesis import given, settings, assume
from hypothesis.strategies import integers, floats, characters, composite, SearchStrategy, lists, text

from typing import List
from f3dasm.src.designofexperiments import DoE

# %%
@composite
def design_space(
    draw: Callable[[SearchStrategy[int]], int], min_value: int = 1, max_value: int = 20
):
    number_of_input_parameters = draw(integers(min_value, max_value))
    number_of_output_parameters = draw(integers(min_value, max_value))

    def get_space(number_of_parameters: int) -> List[SpaceInterface]:
        space = []
        for i in range(number_of_parameters):
            parameter: SpaceInterface = np.random.choice(
                a=['ContinuousSpace', 'DiscreteSpace', 'CategoricalSpace']
            )
            name = draw(
                text(alphabet="abcdefghijklmnopqrstuvwxyz", min_size=10, max_size=10)
            )

            if parameter == 'ContinuousSpace':
                lower_bound, upper_bound = (
                    draw(floats(max_value=0.0)),
                    draw(floats(min_value=0.1)),
                ) 

                space.append(
                    ContinuousSpace(
                        name=name, lower_bound=lower_bound, upper_bound=upper_bound
                    )
                
                )

            elif parameter == 'DiscreteSpace':
                lower_bound, upper_bound = draw(integers(max_value=0)), draw(integers(min_value=1)),

                space.append(
                    DiscreteSpace(
                        name=name, lower_bound=lower_bound, upper_bound=upper_bound
                    )
                )
            elif parameter == 'CategoricalSpace':
                categories = ["test1", "test2"]
                space.append(CategoricalSpace(name=name, categories=categories))

        return space

    design_space = DoE(
        input_space=get_space(number_of_input_parameters),
        output_space=get_space(number_of_output_parameters),
    )
    return design_space

# %%
@given(design_space())
def test_design(design: DoE):
    pass
    print(design)

# %%
test_design()
# Out:
# DoE(input_space=[ContinuousSpace(name='qjjqnfgtxc', lower_bound=0.0, upper_bound=1.6, type='float'), DiscreteSpace(name='niebyaaaaa', lower_bound=-2057, upper_bound=866250811494334851, type='int'), ContinuousSpace(name='bewvwvgoct', lower_bound=-1.1, upper_bound=0.10000011920928961, type='float')], output_space=[DiscreteSpace(name='iaaaaaabac', lower_bound=0, upper_bound=1, type='int'), DiscreteSpace(name='aaapvrqydw', lower_bound=-271, upper_bound=1, type='int'), CategoricalSpace(name='aueaiokgvv', categories=['test1', 'test2'], type='category')])
# DoE(input_space=[ContinuousSpace(name='aaaaaaaaaa', lower_bound=0.0, upper_bound=0.1, type='float')], output_space=[DiscreteSpace(name='aaaaaaaaaa', lower_bound=0, upper_bound=1, type='int')])
# DoE(input_space=[ContinuousSpace(name='aaaaaaaaaa', lower_bound=0.0, upper_bound=0.1, type='float'), DiscreteSpace(name='aaaaaaaaaa', lower_bound=0, upper_bound=1, type='int'), ContinuousSpace(name='aaaaaaaaaa', lower_bound=0.0, upper_bound=0.1, type='float'), DiscreteSpace(name='aaaaaaaaaa', lower_bound=0, upper_bound=1, type='int'), DiscreteSpace(name='aaaaaaaaaa', lower_bound=0, upper_bound=1, type='int'), CategoricalSpace(name='aaaaaaaaaa', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='aaaaaaaaaa', lower_bound=0.0, upper_bound=0.1, type='float'), CategoricalSpace(name='aaaaaaaaaa', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='aaaaaaaaaa', lower_bound=0.0, upper_bound=0.1, type='float'), ContinuousSpace(name='aaaaaaaaaa', lower_bound=0.0, upper_bound=0.1, type='float'), ContinuousSpace(name='aaaaaaaaaa', lower_bound=0.0, upper_bound=0.1, type='float'), CategoricalSpace(name='aaaaaaaaaa', categories=['test1', 'test2'], type='category')], output_space=[DiscreteSpace(name='aaaaaaaaaa', lower_bound=0, upper_bound=1, type='int'), CategoricalSpace(name='aaaaaaaaaa', categories=['test1', 'test2'], type='category'), CategoricalSpace(name='aaaaaaaaaa', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='aaaaaaaaaa', lower_bound=0.0, upper_bound=0.1, type='float'), DiscreteSpace(name='aaaaaaaaaa', lower_bound=0, upper_bound=1, type='int')])
# DoE(input_space=[ContinuousSpace(name='wzkulwbvzp', lower_bound=-3.402823466e+38, upper_bound=4.453029120885705e+16, type='float'), DiscreteSpace(name='rodakomsnn', lower_bound=-12898, upper_bound=18105, type='int'), ContinuousSpace(name='xzcsqdlcve', lower_bound=0.0, upper_bound=1.2000000000000002, type='float'), DiscreteSpace(name='borcfeedjy', lower_bound=-5414, upper_bound=28738, type='int'), DiscreteSpace(name='dfouogllrk', lower_bound=-50, upper_bound=65, type='int'), CategoricalSpace(name='gojskfltlw', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='wllpxmibva', lower_bound=-0.3333333333333333, upper_bound=0.1, type='float'), CategoricalSpace(name='ovwcpabprv', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='dyvhdjfmzs', lower_bound=0.0, upper_bound=9007199254740992.0, type='float'), ContinuousSpace(name='wfwgpcmymy', lower_bound=0.0, upper_bound=inf, type='float'), ContinuousSpace(name='kvromcjxnb', lower_bound=-2.225073858507203e-309, upper_bound=9007199254740992.0, type='float'), CategoricalSpace(name='kvjncglrzz', categories=['test1', 'test2'], type='category')], output_space=[DiscreteSpace(name='sbhowvgobv', lower_bound=-12967, upper_bound=28567, type='int'), CategoricalSpace(name='uqwpqjpjxm', categories=['test1', 'test2'], type='category'), CategoricalSpace(name='mpbftzdkjz', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='dofgvllzzn', lower_bound=0.0, upper_bound=0.1, type='float'), DiscreteSpace(name='ygnfckdwlh', lower_bound=-1768, upper_bound=4, type='int')])
# DoE(input_space=[ContinuousSpace(name='aaaaaaaaaa', lower_bound=0.0, upper_bound=0.1, type='float'), DiscreteSpace(name='aaaaaaaaaa', lower_bound=0, upper_bound=1, type='int'), ContinuousSpace(name='aaaaaaaaaa', lower_bound=0.0, upper_bound=0.1, type='float'), DiscreteSpace(name='aaaaaaaaaa', lower_bound=0, upper_bound=1, type='int'), DiscreteSpace(name='aaaaaaaaaa', lower_bound=0, upper_bound=1, type='int'), CategoricalSpace(name='aaaaaaaaaa', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='aaaaaaaaaa', lower_bound=0.0, upper_bound=0.1, type='float'), CategoricalSpace(name='aaaaaaaaaa', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='aaaaaaaaaa', lower_bound=0.0, upper_bound=0.1, type='float'), ContinuousSpace(name='aaaaaaaaaa', lower_bound=0.0, upper_bound=0.1, type='float')], output_space=[ContinuousSpace(name='aaaaaaaaaa', lower_bound=0.0, upper_bound=0.1, type='float')])
# DoE(input_space=[ContinuousSpace(name='wwwjihngbr', lower_bound=0.0, upper_bound=0.1, type='float'), DiscreteSpace(name='tokxdwuodp', lower_bound=-1616314383, upper_bound=6264, type='int'), ContinuousSpace(name='bpvhlqwzfo', lower_bound=0.0, upper_bound=inf, type='float'), DiscreteSpace(name='vrgdqaaofq', lower_bound=-13151, upper_bound=18, type='int'), DiscreteSpace(name='ngfnlzpgcn', lower_bound=-77, upper_bound=16194, type='int'), CategoricalSpace(name='eldfkwtqrz', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='rqtkccdvjd', lower_bound=0.0, upper_bound=0.1, type='float'), CategoricalSpace(name='cuiadiosit', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='tzycycbhpu', lower_bound=-0.5, upper_bound=5.768919631436599e+16, type='float'), ContinuousSpace(name='kpkgguxten', lower_bound=0.0, upper_bound=0.1, type='float')], output_space=[ContinuousSpace(name='uyljlblwmr', lower_bound=0.0, upper_bound=0.1, type='float')])
# DoE(input_space=[ContinuousSpace(name='aaaaaaaaaa', lower_bound=0.0, upper_bound=0.1, type='float')], output_space=[DiscreteSpace(name='aaaaaaaaaa', lower_bound=0, upper_bound=1, type='int')])
# DoE(input_space=[ContinuousSpace(name='aaaaaaaaaa', lower_bound=0.0, upper_bound=0.1, type='float'), DiscreteSpace(name='aaaaaaaaaa', lower_bound=0, upper_bound=1, type='int'), ContinuousSpace(name='aaaaaaaaaa', lower_bound=0.0, upper_bound=0.1, type='float'), DiscreteSpace(name='aaaaaaaaaa', lower_bound=0, upper_bound=1, type='int')], output_space=[DiscreteSpace(name='aaaaaaaaaa', lower_bound=0, upper_bound=1, type='int')])
# DoE(input_space=[ContinuousSpace(name='ydcivxkurs', lower_bound=0.0, upper_bound=1.2000000000000002, type='float'), DiscreteSpace(name='uwwdyxnzlx', lower_bound=-45548981199481597073830028413068851072, upper_bound=29637, type='int'), ContinuousSpace(name='rndvbclcsw', lower_bound=-0.3333333333333333, upper_bound=0.1, type='float'), DiscreteSpace(name='lqpkmzlwlr', lower_bound=-14691, upper_bound=90, type='int')], output_space=[DiscreteSpace(name='cvgqifkrpc', lower_bound=-14948, upper_bound=22862, type='int'), CategoricalSpace(name='ltljbkvnut', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='dvhlbgafxd', lower_bound=-inf, upper_bound=1.7976931348623157e+308, type='float'), CategoricalSpace(name='yghvawvbbg', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='ibotmodimk', lower_bound=-10000000.0, upper_bound=0.1, type='float'), ContinuousSpace(name='swrozwarvy', lower_bound=-2.220446049250313e-16, upper_bound=0.43333333333333335, type='float'), ContinuousSpace(name='fodbvwfbja', lower_bound=-inf, upper_bound=0.1, type='float')])
# DoE(input_space=[ContinuousSpace(name='aaaaaaaaaa', lower_bound=0.0, upper_bound=0.1, type='float')], output_space=[DiscreteSpace(name='aaaaaaaaaa', lower_bound=0, upper_bound=1, type='int')])
# DoE(input_space=[ContinuousSpace(name='aaaaaaaaaa', lower_bound=0.0, upper_bound=0.1, type='float'), DiscreteSpace(name='aaaaaaaaaa', lower_bound=0, upper_bound=1, type='int'), ContinuousSpace(name='aaaaaaaaaa', lower_bound=0.0, upper_bound=0.1, type='float'), DiscreteSpace(name='aaaaaaaaaa', lower_bound=0, upper_bound=1, type='int'), DiscreteSpace(name='aaaaaaaaaa', lower_bound=0, upper_bound=1, type='int'), CategoricalSpace(name='aaaaaaaaaa', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='aaaaaaaaaa', lower_bound=0.0, upper_bound=0.1, type='float'), CategoricalSpace(name='aaaaaaaaaa', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='aaaaaaaaaa', lower_bound=0.0, upper_bound=0.1, type='float'), ContinuousSpace(name='aaaaaaaaaa', lower_bound=0.0, upper_bound=0.1, type='float'), ContinuousSpace(name='aaaaaaaaaa', lower_bound=0.0, upper_bound=0.1, type='float'), CategoricalSpace(name='aaaaaaaaaa', categories=['test1', 'test2'], type='category'), DiscreteSpace(name='aaaaaaaaaa', lower_bound=0, upper_bound=1, type='int'), CategoricalSpace(name='aaaaaaaaaa', categories=['test1', 'test2'], type='category'), CategoricalSpace(name='aaaaaaaaaa', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='aaaaaaaaaa', lower_bound=0.0, upper_bound=0.1, type='float'), DiscreteSpace(name='aaaaaaaaaa', lower_bound=0, upper_bound=1, type='int'), DiscreteSpace(name='aaaaaaaaaa', lower_bound=0, upper_bound=1, type='int')], output_space=[DiscreteSpace(name='aaaaaaaaaa', lower_bound=0, upper_bound=1, type='int')])
# DoE(input_space=[ContinuousSpace(name='puqlgptpdl', lower_bound=0.0, upper_bound=0.1, type='float'), DiscreteSpace(name='wgeqhdjmph', lower_bound=-8210, upper_bound=23118, type='int'), ContinuousSpace(name='pjhfllrbhx', lower_bound=-1.8894852807127963e-268, upper_bound=0.10001, type='float'), DiscreteSpace(name='dewbembvhl', lower_bound=-112, upper_bound=21561, type='int'), DiscreteSpace(name='viwrrpbnzg', lower_bound=-4802, upper_bound=19301, type='int'), CategoricalSpace(name='cicikgurmr', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='tjwrgxdtlc', lower_bound=-3.402823466e+38, upper_bound=0.1, type='float'), CategoricalSpace(name='rxsywhctot', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='nkuyordreh', lower_bound=-1.440200365033805e+16, upper_bound=2.0, type='float'), ContinuousSpace(name='syunwlxdty', lower_bound=0.0, upper_bound=0.1, type='float'), ContinuousSpace(name='skhqumbdha', lower_bound=0.0, upper_bound=0.10006103515625, type='float'), CategoricalSpace(name='momquulrzh', categories=['test1', 'test2'], type='category'), DiscreteSpace(name='stcqmxmbvc', lower_bound=-4487, upper_bound=17031, type='int'), CategoricalSpace(name='zxpripxapg', categories=['test1', 'test2'], type='category'), CategoricalSpace(name='kjkuxtuofc', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='kojcklwouw', lower_bound=-2.5205217867960384e-57, upper_bound=0.1, type='float'), DiscreteSpace(name='hmwnsttgee', lower_bound=-5, upper_bound=50, type='int'), DiscreteSpace(name='hoczpjyqeh', lower_bound=-98, upper_bound=8074, type='int')], output_space=[DiscreteSpace(name='klyhjnjqcd', lower_bound=-99521126066547667435694072799008501360, upper_bound=9554, type='int'), DiscreteSpace(name='qtbuxknbsi', lower_bound=-16195, upper_bound=11487, type='int'), ContinuousSpace(name='ofheaccfue', lower_bound=-5.196247042752711e+16, upper_bound=0.1, type='float'), DiscreteSpace(name='tjeiikjddc', lower_bound=-17938, upper_bound=115, type='int'), ContinuousSpace(name='dujbyasagd', lower_bound=-0.99999, upper_bound=0.1, type='float'), ContinuousSpace(name='tlyhcrdchl', lower_bound=0.0, upper_bound=0.1, type='float'), DiscreteSpace(name='fvfefvdtlp', lower_bound=-1791379203, upper_bound=5466, type='int'), CategoricalSpace(name='tnihcvkbeg', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='xnnryihrtl', lower_bound=0.0, upper_bound=inf, type='float'), CategoricalSpace(name='bgyxblzzcy', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='xbinupfinq', lower_bound=-5e-324, upper_bound=0.1, type='float'), DiscreteSpace(name='jxclqrpqdw', lower_bound=-4, upper_bound=18536, type='int')])
# DoE(input_space=[ContinuousSpace(name='gxpdhaxxzl', lower_bound=0.0, upper_bound=0.1, type='float'), DiscreteSpace(name='iamovpthye', lower_bound=-33, upper_bound=17420, type='int'), ContinuousSpace(name='snpedpeizf', lower_bound=0.0, upper_bound=0.1, type='float'), DiscreteSpace(name='kqknivwpuk', lower_bound=-576375557, upper_bound=72, type='int'), DiscreteSpace(name='zjhhjqfdrh', lower_bound=-42, upper_bound=13, type='int'), CategoricalSpace(name='pduszajysf', categories=['test1', 'test2'], type='category')], output_space=[ContinuousSpace(name='btactlvjjx', lower_bound=0.0, upper_bound=0.1, type='float'), CategoricalSpace(name='rxzgcdohvp', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='csvotvzgzo', lower_bound=0.0, upper_bound=inf, type='float'), ContinuousSpace(name='rrhptlsrti', lower_bound=0.0, upper_bound=0.43333333333333335, type='float'), ContinuousSpace(name='dtrfymlimw', lower_bound=-1e-05, upper_bound=0.1, type='float')])
# DoE(input_space=[ContinuousSpace(name='vgwzrzjdfh', lower_bound=-1.1993463530095974e+16, upper_bound=3.820103531536332e+124, type='float'), DiscreteSpace(name='icpsrqebpj', lower_bound=-105074857077540521174721174947328369920, upper_bound=3303, type='int'), ContinuousSpace(name='hzggxaavce', lower_bound=0.0, upper_bound=0.1, type='float'), DiscreteSpace(name='tuuldwhypy', lower_bound=-20373, upper_bound=9050, type='int'), DiscreteSpace(name='penywlqdst', lower_bound=-5, upper_bound=21, type='int'), CategoricalSpace(name='rvustnarzv', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='opyserudrl', lower_bound=-5.877288799937153e+16, upper_bound=inf, type='float'), CategoricalSpace(name='sxmnvixewx', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='mfosxugpkb', lower_bound=0.0, upper_bound=5.167977236767389e+16, type='float'), ContinuousSpace(name='csmzddvgyn', lower_bound=-2.2250738585e-313, upper_bound=7.17542906207125e+16, type='float'), ContinuousSpace(name='pkvbezksdm', lower_bound=-1.7976931348623157e+308, upper_bound=9007199254740992.0, type='float'), CategoricalSpace(name='vtlniztdfk', categories=['test1', 'test2'], type='category')], output_space=[DiscreteSpace(name='wtzncltmqy', lower_bound=-17, upper_bound=53042095015387033568237199748908055309, type='int'), CategoricalSpace(name='yygutovbje', categories=['test1', 'test2'], type='category'), CategoricalSpace(name='kxtxkdgraw', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='nlwuakkpfa', lower_bound=-4.608855491978791e-265, upper_bound=2.0, type='float'), DiscreteSpace(name='fnesuunhqz', lower_bound=-1468002116, upper_bound=21612, type='int'), DiscreteSpace(name='kapxyjhjaz', lower_bound=-384831784, upper_bound=28790, type='int'), DiscreteSpace(name='viuzqgjptb', lower_bound=-869, upper_bound=5608291084685939482, type='int'), DiscreteSpace(name='cjlrkedggg', lower_bound=-58, upper_bound=5712930934234271413, type='int'), ContinuousSpace(name='wrijdjscix', lower_bound=0.0, upper_bound=1.09999, type='float'), DiscreteSpace(name='bqleecrnqk', lower_bound=-24068, upper_bound=16709, type='int'), ContinuousSpace(name='gqhcottzrb', lower_bound=0.0, upper_bound=6.942340243345156e+16, type='float'), ContinuousSpace(name='buucojquis', lower_bound=0.0, upper_bound=1.2000000000000002, type='float'), DiscreteSpace(name='rufckjezus', lower_bound=-108, upper_bound=1333798367, type='int')])
# DoE(input_space=[ContinuousSpace(name='mvgwzrzjdf', lower_bound=-0.0, upper_bound=845085766113756.1, type='float'), DiscreteSpace(name='vcaicpsrqe', lower_bound=-50462927, upper_bound=110, type='int'), ContinuousSpace(name='ytysrdugka', lower_bound=0.0, upper_bound=0.1, type='float'), DiscreteSpace(name='xaavceaycb', lower_bound=-1288490188, upper_bound=11, type='int'), DiscreteSpace(name='ldwhypyeca', lower_bound=-35, upper_bound=519, type='int'), CategoricalSpace(name='ywlqdstbdd', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='ddcakbcajr', lower_bound=-1.401298464324817e-45, upper_bound=1144677555309313.0, type='float'), CategoricalSpace(name='avqnbxazib', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='bqaaaaaaas', lower_bound=-0.3333333333333333, upper_bound=0.1, type='float'), ContinuousSpace(name='fazxkmbcsm', lower_bound=-9007199254740992.0, upper_bound=9007199254740992.0, type='float'), ContinuousSpace(name='mflogsbpkv', lower_bound=-1.5, upper_bound=281612415664128.1, type='float'), CategoricalSpace(name='abvtlniztd', categories=['test1', 'test2'], type='category'), DiscreteSpace(name='fkwtzncltm', lower_bound=-2, upper_bound=18, type='int')], output_space=[CategoricalSpace(name='ehgbppscwh', categories=['test1', 'test2'], type='category'), CategoricalSpace(name='roxkttwzyy', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='gutovbjekx', lower_bound=-4785169312192020.0, upper_bound=4227622226034934.0, type='float'), DiscreteSpace(name='ahkvragbag', lower_bound=-1678, upper_bound=2567, type='int'), DiscreteSpace(name='hqzbdbojda', lower_bound=0, upper_bound=901, type='int'), DiscreteSpace(name='azfbbnacra', lower_bound=-117, upper_bound=13, type='int'), DiscreteSpace(name='qgjptbfabg', lower_bound=-642, upper_bound=5608291084685939482, type='int'), ContinuousSpace(name='cjlrkedggg', lower_bound=0.0, upper_bound=846205476197666.1, type='float'), DiscreteSpace(name='jwrijdjsci', lower_bound=-5379, upper_bound=6, type='int'), ContinuousSpace(name='ofonbbqlee', lower_bound=0.0, upper_bound=0.10000000000000023, type='float'), ContinuousSpace(name='jgqhcottzr', lower_bound=-26348084492581.0, upper_bound=0.43333333333333335, type='float'), DiscreteSpace(name='uisafgbafz', lower_bound=-1288489984, upper_bound=3, type='int')])
# DoE(input_space=[ContinuousSpace(name='varvzzfvqf', lower_bound=-1.1, upper_bound=1.7109237494107176e+16, type='float'), DiscreteSpace(name='uqlhehaijj', lower_bound=-2891, upper_bound=13200, type='int'), ContinuousSpace(name='bfurfiaeze', lower_bound=-2.00001, upper_bound=1.7976931348623157e+308, type='float'), DiscreteSpace(name='hzelusoqza', lower_bound=-114, upper_bound=23991, type='int'), DiscreteSpace(name='iswcowurfj', lower_bound=-12408, upper_bound=1424, type='int')], output_space=[CategoricalSpace(name='dobyhkzvri', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='qgicwfzsoa', lower_bound=0.0, upper_bound=4.108564452513447e+16, type='float'), CategoricalSpace(name='nvplezqbdb', categories=['test1', 'test2'], type='category')])
# DoE(input_space=[ContinuousSpace(name='varvzzfvqf', lower_bound=-1.1, upper_bound=1.7109237494107176e+16, type='float'), DiscreteSpace(name='uqlhehaijj', lower_bound=-2891, upper_bound=13200, type='int'), ContinuousSpace(name='bfurfiaeze', lower_bound=-2.00001, upper_bound=1.7976931348623157e+308, type='float')], output_space=[DiscreteSpace(name='hzelusoqza', lower_bound=-114, upper_bound=23991, type='int'), DiscreteSpace(name='iswcowurfj', lower_bound=-12408, upper_bound=1424, type='int'), CategoricalSpace(name='dobyhkzvri', categories=['test1', 'test2'], type='category')])
# DoE(input_space=[ContinuousSpace(name='xqhezbfmgi', lower_bound=-inf, upper_bound=0.10000011920928961, type='float'), DiscreteSpace(name='qexcudbbln', lower_bound=-25886, upper_bound=19080, type='int'), ContinuousSpace(name='atwhmjjyff', lower_bound=-2.00001, upper_bound=0.1, type='float'), DiscreteSpace(name='tkhjrmkqlw', lower_bound=-26437, upper_bound=5, type='int'), DiscreteSpace(name='bcgmcdzlyw', lower_bound=-14035, upper_bound=107, type='int'), CategoricalSpace(name='tnzmnpoybm', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='gdjbmjswoh', lower_bound=-6.103515625e-05, upper_bound=0.1, type='float'), CategoricalSpace(name='ojtgzticfg', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='cwktzsvvzu', lower_bound=0.0, upper_bound=inf, type='float'), ContinuousSpace(name='ujoryrhlgm', lower_bound=-1.175494351e-38, upper_bound=2.10001, type='float'), ContinuousSpace(name='npohqxxsst', lower_bound=0.0, upper_bound=2.10001, type='float'), CategoricalSpace(name='yxjhbbcaiv', categories=['test1', 'test2'], type='category'), DiscreteSpace(name='xattttbxuy', lower_bound=-80, upper_bound=115, type='int'), CategoricalSpace(name='bhkswvyrrx', categories=['test1', 'test2'], type='category'), CategoricalSpace(name='ejrtinfhwc', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='vcotcmfcjn', lower_bound=0.0, upper_bound=1.399491345644812e+16, type='float'), DiscreteSpace(name='rwaaevolgc', lower_bound=-7445410230145803157, upper_bound=18023, type='int'), DiscreteSpace(name='otzouasnnt', lower_bound=-9470, upper_bound=1112148529, type='int'), DiscreteSpace(name='vpmaxyjycn', lower_bound=-83, upper_bound=100, type='int')], output_space=[DiscreteSpace(name='bypyoagnog', lower_bound=-540742650, upper_bound=2989, type='int'), ContinuousSpace(name='xgjbjfgcxa', lower_bound=0.0, upper_bound=0.1, type='float'), DiscreteSpace(name='xwafnwunik', lower_bound=-8998, upper_bound=30035548685087412132125316232514162130, type='int'), ContinuousSpace(name='vkojsnagre', lower_bound=-2.9867396431487715e-176, upper_bound=0.10001, type='float'), ContinuousSpace(name='yduyyomrhq', lower_bound=0.0, upper_bound=0.1, type='float'), DiscreteSpace(name='wxcohputqa', lower_bound=-7984, upper_bound=24, type='int'), CategoricalSpace(name='zzwzbqqmey', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='xolylugyxu', lower_bound=-9007199254740992.0, upper_bound=0.1, type='float')])
# DoE(input_space=[ContinuousSpace(name='gdcbyfbqka', lower_bound=-1.401298464324817e-45, upper_bound=inf, type='float'), DiscreteSpace(name='fxsadtuoqm', lower_bound=-127, upper_bound=5, type='int'), ContinuousSpace(name='boccqpzziu', lower_bound=0.0, upper_bound=inf, type='float'), DiscreteSpace(name='bjmoojcobg', lower_bound=-3950909153968113731, upper_bound=2334, type='int'), DiscreteSpace(name='ckzhnmnvmk', lower_bound=-23610, upper_bound=3943, type='int'), CategoricalSpace(name='iiedqqtawp', categories=['test1', 'test2'], type='category')], output_space=[ContinuousSpace(name='uzfcobgbrq', lower_bound=0.0, upper_bound=inf, type='float'), CategoricalSpace(name='mqkiafvszc', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='voualxlmsq', lower_bound=-2.220446049250313e-16, upper_bound=2.2789950378518136e+16, type='float'), ContinuousSpace(name='amektxwqar', lower_bound=0.0, upper_bound=3.402823466e+38, type='float'), ContinuousSpace(name='zpqrjgxkqo', lower_bound=0.0, upper_bound=0.1, type='float'), CategoricalSpace(name='kucurnkvst', categories=['test1', 'test2'], type='category'), DiscreteSpace(name='hdhkauqqyg', lower_bound=-31616, upper_bound=85, type='int'), CategoricalSpace(name='ssdanwavon', categories=['test1', 'test2'], type='category'), CategoricalSpace(name='gtegigtdzh', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='wvcebgzlij', lower_bound=0.0, upper_bound=10000000.1, type='float'), DiscreteSpace(name='kfszynsyyo', lower_bound=-12222, upper_bound=20, type='int'), DiscreteSpace(name='hhyurlcyor', lower_bound=-31854, upper_bound=9806, type='int'), DiscreteSpace(name='wtdxymgoct', lower_bound=-29701, upper_bound=17933, type='int')])
# DoE(input_space=[ContinuousSpace(name='ozxwnixjti', lower_bound=-1.175494351e-38, upper_bound=1.2000000000000002, type='float'), DiscreteSpace(name='pmhcxygxbk', lower_bound=-25859, upper_bound=116, type='int'), ContinuousSpace(name='dctsrcqrkl', lower_bound=0.0, upper_bound=0.1, type='float'), DiscreteSpace(name='hcdxarsqbj', lower_bound=-1928932800, upper_bound=31445, type='int'), DiscreteSpace(name='jcbhyuxhvx', lower_bound=-12012, upper_bound=17986, type='int'), CategoricalSpace(name='meddxkzxtm', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='gjufgyrckg', lower_bound=0.0, upper_bound=2.10001, type='float'), CategoricalSpace(name='axfqexskkz', categories=['test1', 'test2'], type='category')], output_space=[ContinuousSpace(name='uqqcmzextx', lower_bound=0.0, upper_bound=0.1, type='float'), ContinuousSpace(name='ymbenhsdja', lower_bound=-inf, upper_bound=0.1, type='float'), ContinuousSpace(name='vtdqmbmosg', lower_bound=0.0, upper_bound=inf, type='float'), CategoricalSpace(name='hratassoft', categories=['test1', 'test2'], type='category'), DiscreteSpace(name='cpojtyajqq', lower_bound=-48, upper_bound=19489, type='int'), CategoricalSpace(name='cbcjkklyqp', categories=['test1', 'test2'], type='category'), CategoricalSpace(name='lnbxuigasb', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='tigajmubmv', lower_bound=-inf, upper_bound=5.005548809625974e+16, type='float'), DiscreteSpace(name='rwaodynczn', lower_bound=-23720, upper_bound=11673, type='int'), DiscreteSpace(name='lgbdzgaaef', lower_bound=-21829, upper_bound=32476, type='int'), DiscreteSpace(name='lvmrbrrwgb', lower_bound=-11312, upper_bound=28253, type='int'), DiscreteSpace(name='xjppazcznt', lower_bound=-13688, upper_bound=29879, type='int')])
# DoE(input_space=[ContinuousSpace(name='isbkczbftk', lower_bound=-1.175494351e-38, upper_bound=3.887759538542138e+16, type='float'), DiscreteSpace(name='ljkojwmhet', lower_bound=-20050, upper_bound=100779891868309843262280494551238406641, type='int'), ContinuousSpace(name='mhnglrvadw', lower_bound=0.0, upper_bound=1.2000000000000002, type='float'), DiscreteSpace(name='sbfncxqoxf', lower_bound=-17662, upper_bound=143270589580910553013977126911602917576, type='int'), DiscreteSpace(name='icwjgorvdb', lower_bound=-1840, upper_bound=2044, type='int'), CategoricalSpace(name='mnffxyaxrx', categories=['test1', 'test2'], type='category')], output_space=[ContinuousSpace(name='lfdrpssttu', lower_bound=0.0, upper_bound=0.1, type='float'), CategoricalSpace(name='qyebzwwrzt', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='wbrklftvfc', lower_bound=-1.7976931348623157e+308, upper_bound=inf, type='float'), ContinuousSpace(name='zrxvondnyi', lower_bound=0.0, upper_bound=0.10000005960464478, type='float'), ContinuousSpace(name='qjtrtfueut', lower_bound=-2.225073858507e-311, upper_bound=5.218187898987323e+16, type='float'), CategoricalSpace(name='wfkawuprml', categories=['test1', 'test2'], type='category'), DiscreteSpace(name='bvlpgfmirc', lower_bound=-26310562272407246634819377887840580403, upper_bound=22968, type='int'), CategoricalSpace(name='cstqtqfvso', categories=['test1', 'test2'], type='category'), CategoricalSpace(name='cmzxhzkczv', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='rclrwwcfff', lower_bound=-inf, upper_bound=1.7976931348623157e+308, type='float'), DiscreteSpace(name='fcqndkbvya', lower_bound=-109, upper_bound=5795, type='int'), DiscreteSpace(name='prwudmmfcr', lower_bound=-107, upper_bound=27390, type='int'), DiscreteSpace(name='rntizhikem', lower_bound=-71, upper_bound=956162737, type='int'), DiscreteSpace(name='sljbtwcnsq', lower_bound=-70041556928982106106522222112627844525, upper_bound=23090, type='int'), ContinuousSpace(name='deuqmpkeqh', lower_bound=0.0, upper_bound=1.6, type='float'), DiscreteSpace(name='htcrndymvi', lower_bound=-30101, upper_bound=6, type='int'), ContinuousSpace(name='hbulekcuvc', lower_bound=0.0, upper_bound=2.130740023267631e+16, type='float'), ContinuousSpace(name='uelurhzncd', lower_bound=0.0, upper_bound=0.1, type='float')])
# DoE(input_space=[ContinuousSpace(name='isbkczbftk', lower_bound=-1.175494351e-38, upper_bound=3.887759538542138e+16, type='float'), DiscreteSpace(name='ljkojwmhet', lower_bound=-20050, upper_bound=100779891868309843262280494551238406641, type='int'), ContinuousSpace(name='mhnglrvadw', lower_bound=0.0, upper_bound=1.2000000000000002, type='float'), DiscreteSpace(name='sbfncxqoxf', lower_bound=-17662, upper_bound=143270589580910553013977126911602917576, type='int'), DiscreteSpace(name='icwjgorvdb', lower_bound=-1840, upper_bound=2044, type='int'), CategoricalSpace(name='mnffxyaxrx', categories=['test1', 'test2'], type='category')], output_space=[ContinuousSpace(name='lfdrpssttu', lower_bound=0.0, upper_bound=0.1, type='float'), CategoricalSpace(name='qyebzwwrzt', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='wbrklftvfc', lower_bound=-1.7976931348623157e+308, upper_bound=inf, type='float'), ContinuousSpace(name='zrxvondnyi', lower_bound=0.0, upper_bound=0.10000005960464478, type='float'), ContinuousSpace(name='qjtrtfueut', lower_bound=-2.225073858507e-311, upper_bound=5.218187898987323e+16, type='float'), CategoricalSpace(name='wfkawuprml', categories=['test1', 'test2'], type='category')])
# DoE(input_space=[ContinuousSpace(name='isbkczbntk', lower_bound=-1.175494351e-38, upper_bound=3.887759538542138e+16, type='float'), DiscreteSpace(name='ljkojwmhet', lower_bound=-20050, upper_bound=100779891868309843262280494551238406641, type='int'), ContinuousSpace(name='mhnglrvadw', lower_bound=0.0, upper_bound=1.2000000000000002, type='float'), DiscreteSpace(name='sbfncxqoxf', lower_bound=-17662, upper_bound=143270589580910553013977126911602917576, type='int'), DiscreteSpace(name='icwjgorvdb', lower_bound=-1840, upper_bound=2044, type='int'), CategoricalSpace(name='mnffxyaxrx', categories=['test1', 'test2'], type='category')], output_space=[ContinuousSpace(name='lfdrpssttu', lower_bound=0.0, upper_bound=0.1, type='float'), CategoricalSpace(name='qyebzwwrzt', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='wbrklftvfc', lower_bound=-1.7976931348623157e+308, upper_bound=inf, type='float'), ContinuousSpace(name='zrxvondnyi', lower_bound=0.0, upper_bound=0.10000005960464478, type='float'), ContinuousSpace(name='qjtrtfueut', lower_bound=-2.225073858507e-311, upper_bound=5.218187898987323e+16, type='float'), CategoricalSpace(name='wfkawuprml', categories=['test1', 'test2'], type='category')])
# DoE(input_space=[ContinuousSpace(name='ahznbkxuok', lower_bound=0.0, upper_bound=0.1, type='float'), DiscreteSpace(name='srjcgpxiih', lower_bound=-24264, upper_bound=84, type='int'), ContinuousSpace(name='plqsotwcbd', lower_bound=0.0, upper_bound=inf, type='float'), DiscreteSpace(name='mpkgujmwln', lower_bound=-1149245697, upper_bound=25962, type='int'), DiscreteSpace(name='hvtchgtvqa', lower_bound=-15815, upper_bound=80, type='int'), CategoricalSpace(name='nqpfqdafvr', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='whebjvzlee', lower_bound=-0.5, upper_bound=1.6, type='float'), CategoricalSpace(name='nhfnpradlr', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='rikmtcvxus', lower_bound=0.0, upper_bound=0.1, type='float'), ContinuousSpace(name='kndsqjaogx', lower_bound=-2.2250738585e-313, upper_bound=0.43333333333333335, type='float'), ContinuousSpace(name='wbslzzfmal', lower_bound=0.0, upper_bound=0.1, type='float'), CategoricalSpace(name='daoxasweai', categories=['test1', 'test2'], type='category'), DiscreteSpace(name='qesxsgopuj', lower_bound=-21358, upper_bound=1526, type='int'), CategoricalSpace(name='sywqfgaavk', categories=['test1', 'test2'], type='category'), CategoricalSpace(name='wpglafprod', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='ggsvvzblcj', lower_bound=0.0, upper_bound=inf, type='float'), DiscreteSpace(name='uenlfuoixb', lower_bound=-72, upper_bound=19752, type='int'), DiscreteSpace(name='wtmtopuekg', lower_bound=-5909481939223347330, upper_bound=31979, type='int')], output_space=[DiscreteSpace(name='pzdozsquqf', lower_bound=-11821, upper_bound=38, type='int'), DiscreteSpace(name='wnyaqlgjpd', lower_bound=-29360, upper_bound=20535, type='int'), ContinuousSpace(name='jvdmlgbdjq', lower_bound=-1.1, upper_bound=3.1484701302026456e+16, type='float'), DiscreteSpace(name='zlbnbvcnxm', lower_bound=-2, upper_bound=6, type='int'), ContinuousSpace(name='mkrxgclhvp', lower_bound=0.0, upper_bound=1.6, type='float'), ContinuousSpace(name='teuygkvknv', lower_bound=0.0, upper_bound=0.43333333333333335, type='float'), DiscreteSpace(name='ddifjoclfi', lower_bound=-1045, upper_bound=37, type='int'), CategoricalSpace(name='ffqubxfkpr', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='wtakyjogjv', lower_bound=-2.220446049250313e-16, upper_bound=0.1, type='float')])
# DoE(input_space=[ContinuousSpace(name='ahznbkxuok', lower_bound=0.0, upper_bound=0.1, type='float'), DiscreteSpace(name='srjcgpxiih', lower_bound=-24264, upper_bound=84, type='int'), ContinuousSpace(name='plqsotwcbd', lower_bound=0.0, upper_bound=inf, type='float'), DiscreteSpace(name='mpkgujmwln', lower_bound=-1149245697, upper_bound=25962, type='int'), DiscreteSpace(name='hvtchgtvqa', lower_bound=-15815, upper_bound=80, type='int'), CategoricalSpace(name='nqpfqdafvr', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='whebjvzlee', lower_bound=-0.5, upper_bound=1.6, type='float'), CategoricalSpace(name='nhfnpradlr', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='rikmtcvxus', lower_bound=0.0, upper_bound=0.1, type='float'), ContinuousSpace(name='kndsqjaogx', lower_bound=-2.2250738585e-313, upper_bound=0.43333333333333335, type='float'), ContinuousSpace(name='wbslzzfmal', lower_bound=0.0, upper_bound=0.1, type='float'), CategoricalSpace(name='daoxasweai', categories=['test1', 'test2'], type='category'), DiscreteSpace(name='qesxsgopuj', lower_bound=-21358, upper_bound=1526, type='int'), CategoricalSpace(name='sywqfgaavk', categories=['test1', 'test2'], type='category'), CategoricalSpace(name='wpglafprod', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='ggsvvzblcj', lower_bound=0.0, upper_bound=inf, type='float'), DiscreteSpace(name='uenlfuoixb', lower_bound=-72, upper_bound=19752, type='int'), DiscreteSpace(name='wtmtopuekg', lower_bound=-5909481939223347330, upper_bound=31979, type='int')], output_space=[DiscreteSpace(name='pzdozsquqf', lower_bound=-11821, upper_bound=38, type='int'), DiscreteSpace(name='wnyaqlgjpd', lower_bound=-29360, upper_bound=20535, type='int'), ContinuousSpace(name='jvdmlgbdjq', lower_bound=-1.1, upper_bound=3.1484701302026456e+16, type='float'), DiscreteSpace(name='zlbnbvcnxm', lower_bound=-2, upper_bound=6, type='int'), ContinuousSpace(name='mkrxgclhvp', lower_bound=0.0, upper_bound=1.6, type='float'), ContinuousSpace(name='teuygkvknv', lower_bound=0.0, upper_bound=0.43333333333333335, type='float'), DiscreteSpace(name='ddifjoclfi', lower_bound=-1045, upper_bound=37, type='int'), CategoricalSpace(name='ffqubxfkpr', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='wtakyjogjv', lower_bound=-2.220446049250313e-16, upper_bound=0.1, type='float'), CategoricalSpace(name='mlckiecwtl', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='sgnveblayy', lower_bound=0.0, upper_bound=3144872220357041.0, type='float'), DiscreteSpace(name='sdlduyjduz', lower_bound=-342586401, upper_bound=22463, type='int'), DiscreteSpace(name='lojzmczvgt', lower_bound=-4116, upper_bound=10575, type='int'), CategoricalSpace(name='zlgercockg', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='btgeyraefh', lower_bound=0.0, upper_bound=5.451297155890014e+133, type='float'), DiscreteSpace(name='bggrkaolgd', lower_bound=-45080568836046707014261985269761216415, upper_bound=27428, type='int'), DiscreteSpace(name='ibetzzucxu', lower_bound=-30814, upper_bound=2091489937188690594, type='int'), DiscreteSpace(name='dowexvdvda', lower_bound=-6, upper_bound=5517, type='int')])
# DoE(input_space=[ContinuousSpace(name='vemolalywa', lower_bound=0.0, upper_bound=0.1, type='float'), DiscreteSpace(name='cjnuxmmjti', lower_bound=-25190862830424315708758446303391175013, upper_bound=18740, type='int'), ContinuousSpace(name='nnktceoeny', lower_bound=0.0, upper_bound=1.5607450968690742e+281, type='float'), DiscreteSpace(name='jzlbhufdpn', lower_bound=-22685, upper_bound=1472715759, type='int'), DiscreteSpace(name='hvrmmdxoen', lower_bound=-78, upper_bound=30421, type='int'), CategoricalSpace(name='cdnpqkqwcq', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='plviwbijww', lower_bound=0.0, upper_bound=1.6861566426119302e+55, type='float'), CategoricalSpace(name='ckrcffybnu', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='tsmkdvbola', lower_bound=0.0, upper_bound=2.0, type='float'), ContinuousSpace(name='axkvllvtxi', lower_bound=-1.7976931348623157e+308, upper_bound=0.1, type='float'), ContinuousSpace(name='ykrhgdkuug', lower_bound=0.0, upper_bound=6.373521093492974e+16, type='float'), CategoricalSpace(name='cittozqtgc', categories=['test1', 'test2'], type='category'), DiscreteSpace(name='ehsibjgtcw', lower_bound=-18508, upper_bound=32516, type='int'), CategoricalSpace(name='dwevwwdeuf', categories=['test1', 'test2'], type='category'), CategoricalSpace(name='nvqmziihpm', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='fmrdbqenfi', lower_bound=-1e-05, upper_bound=inf, type='float'), DiscreteSpace(name='equvxkclrn', lower_bound=-21031, upper_bound=21305, type='int')], output_space=[DiscreteSpace(name='hegiowadfg', lower_bound=-30227, upper_bound=3111, type='int'), DiscreteSpace(name='zaiqlsdlpr', lower_bound=-29168, upper_bound=30775, type='int'), DiscreteSpace(name='bstphmamfi', lower_bound=-35, upper_bound=7747, type='int'), ContinuousSpace(name='nsxuznzecv', lower_bound=-0.3333333333333333, upper_bound=0.10001, type='float'), DiscreteSpace(name='mxftljadhx', lower_bound=-6067, upper_bound=2, type='int'), ContinuousSpace(name='zkdixhxhcb', lower_bound=-2.225073858507203e-309, upper_bound=2.692587605969196e+16, type='float'), ContinuousSpace(name='xhegshrkoh', lower_bound=-8.031325912444523e+49, upper_bound=0.1, type='float'), DiscreteSpace(name='mdnxiajihk', lower_bound=-14876, upper_bound=30149, type='int'), CategoricalSpace(name='rjbtbmzcch', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='wwnyhmjbon', lower_bound=-3.402823466e+38, upper_bound=3.039881772179828e+16, type='float'), CategoricalSpace(name='rwplunfzlr', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='dupyrimpxr', lower_bound=0.0, upper_bound=0.1, type='float')])
# DoE(input_space=[ContinuousSpace(name='txorwzhcjt', lower_bound=-0.5, upper_bound=1.6, type='float'), DiscreteSpace(name='pclvrzdtzw', lower_bound=-70, upper_bound=20661, type='int'), ContinuousSpace(name='wbjyzdagsv', lower_bound=-2.220446049250313e-16, upper_bound=0.1, type='float'), DiscreteSpace(name='rotdxykbci', lower_bound=-28, upper_bound=16862, type='int'), DiscreteSpace(name='mlkjofyalg', lower_bound=-116, upper_bound=33, type='int')], output_space=[CategoricalSpace(name='xxanfbicmr', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='mrsfhwdjow', lower_bound=0.0, upper_bound=0.1, type='float'), CategoricalSpace(name='bupdcwbcwg', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='bnfisaagtn', lower_bound=0.0, upper_bound=0.1, type='float'), ContinuousSpace(name='rcgnczopbf', lower_bound=0.0, upper_bound=0.1, type='float'), ContinuousSpace(name='bvqypallsa', lower_bound=-3.402823466e+38, upper_bound=0.1, type='float'), CategoricalSpace(name='zqbaqdpnzv', categories=['test1', 'test2'], type='category'), DiscreteSpace(name='nlgsiesgni', lower_bound=-53, upper_bound=1666984194592240394, type='int'), CategoricalSpace(name='ndnchjaymp', categories=['test1', 'test2'], type='category'), CategoricalSpace(name='xoeqnbeztv', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='oaozdowvmj', lower_bound=-5.504992023843423e+101, upper_bound=0.1, type='float'), DiscreteSpace(name='pzdifarssn', lower_bound=-85, upper_bound=6631573202902147339, type='int')])
# DoE(input_space=[ContinuousSpace(name='ckfaomdpnc', lower_bound=-2.00001, upper_bound=0.10001, type='float'), DiscreteSpace(name='bxtzvmuplo', lower_bound=-1070547680, upper_bound=6246, type='int'), ContinuousSpace(name='qcuzsoagdu', lower_bound=0.0, upper_bound=4.876197619191796e+55, type='float'), DiscreteSpace(name='khcqayfhgo', lower_bound=-5705, upper_bound=11244, type='int')], output_space=[DiscreteSpace(name='qwntovvnqg', lower_bound=-89, upper_bound=15046, type='int'), CategoricalSpace(name='vifnyuzvuf', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='fwmvcudbvl', lower_bound=0.0, upper_bound=3.50886992532832e+25, type='float'), CategoricalSpace(name='onjsywwdwu', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='wlmmwtlgpi', lower_bound=0.0, upper_bound=0.1, type='float'), ContinuousSpace(name='ahmkhajxtf', lower_bound=-0.99999, upper_bound=0.1, type='float'), ContinuousSpace(name='jomtfjwwrz', lower_bound=-10000000.0, upper_bound=0.1, type='float'), CategoricalSpace(name='wvnisvtbke', categories=['test1', 'test2'], type='category'), DiscreteSpace(name='ieulqszuju', lower_bound=-106, upper_bound=1589746829057455487, type='int'), CategoricalSpace(name='ryvbgdxzju', categories=['test1', 'test2'], type='category'), CategoricalSpace(name='coxcslfahk', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='skirfrehdv', lower_bound=0.0, upper_bound=0.6, type='float')])
# DoE(input_space=[ContinuousSpace(name='wizqsoewuu', lower_bound=-2.225073858507203e-309, upper_bound=1.6, type='float'), DiscreteSpace(name='qaakjuyxbn', lower_bound=-29212, upper_bound=120, type='int'), ContinuousSpace(name='inwjxnyatm', lower_bound=-1.1, upper_bound=0.10001, type='float'), DiscreteSpace(name='gsbobtashs', lower_bound=-27809, upper_bound=372, type='int'), DiscreteSpace(name='imvpfkrfmc', lower_bound=-406, upper_bound=22660, type='int'), CategoricalSpace(name='fzfpaqkluq', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='ezevijoxgo', lower_bound=0.0, upper_bound=2.0, type='float'), CategoricalSpace(name='eevfxzytfq', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='wwjmfaicmr', lower_bound=-0.3333333333333333, upper_bound=0.10000000000000023, type='float'), ContinuousSpace(name='olsrhndwwi', lower_bound=0.0, upper_bound=0.10001, type='float'), ContinuousSpace(name='awwfvotkwo', lower_bound=0.0, upper_bound=0.10000005960464478, type='float'), CategoricalSpace(name='pxwepdfccw', categories=['test1', 'test2'], type='category'), DiscreteSpace(name='dollwplpjf', lower_bound=-129063561166611047419291215437063865454, upper_bound=13819, type='int'), CategoricalSpace(name='lqchgjxmlw', categories=['test1', 'test2'], type='category'), CategoricalSpace(name='zslbucmphq', categories=['test1', 'test2'], type='category')], output_space=[ContinuousSpace(name='kotfjnxens', lower_bound=0.0, upper_bound=0.1, type='float'), DiscreteSpace(name='nimovpuxzv', lower_bound=-24652, upper_bound=991, type='int')])
# DoE(input_space=[ContinuousSpace(name='vjvwytvzjk', lower_bound=-4.866228010600611e+16, upper_bound=3.402823466e+38, type='float'), DiscreteSpace(name='fwxetqnern', lower_bound=-92, upper_bound=5909, type='int'), ContinuousSpace(name='bvivoaetpr', lower_bound=0.0, upper_bound=inf, type='float'), DiscreteSpace(name='nvnoqpblxx', lower_bound=-13969, upper_bound=5445, type='int'), DiscreteSpace(name='lbakpnohou', lower_bound=-5995, upper_bound=21231, type='int'), CategoricalSpace(name='ugrzwuyqse', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='nbvypykoug', lower_bound=-5.384309636006993e+16, upper_bound=0.1, type='float'), CategoricalSpace(name='tlkebigxbs', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='rgrijpwqyx', lower_bound=-6.412055634644621e-196, upper_bound=0.10000000000000023, type='float'), ContinuousSpace(name='dwmwkgyxhb', lower_bound=0.0, upper_bound=0.1, type='float'), ContinuousSpace(name='vkhczuxdpz', lower_bound=-1.192092896e-07, upper_bound=0.1, type='float'), CategoricalSpace(name='stfjsgmkzx', categories=['test1', 'test2'], type='category'), DiscreteSpace(name='fackdyhqmr', lower_bound=-32640, upper_bound=3267145547377068008, type='int'), CategoricalSpace(name='gwcsknqrih', categories=['test1', 'test2'], type='category')], output_space=[CategoricalSpace(name='ylpddxuvvp', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='gmmuaamwgd', lower_bound=-1.192092896e-07, upper_bound=0.10006103515625, type='float')])
# DoE(input_space=[ContinuousSpace(name='ymbycigvum', lower_bound=-2.225073858507203e-309, upper_bound=0.10000000000000023, type='float'), DiscreteSpace(name='dulyoeaevm', lower_bound=-23146, upper_bound=28378, type='int'), ContinuousSpace(name='iblnsxupcc', lower_bound=0.0, upper_bound=inf, type='float'), DiscreteSpace(name='zrvsycgzlo', lower_bound=-19555, upper_bound=30320, type='int'), DiscreteSpace(name='prljwsiolk', lower_bound=-73, upper_bound=769, type='int')], output_space=[CategoricalSpace(name='okbhjixgar', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='rkaytpvnmb', lower_bound=0.0, upper_bound=0.1, type='float'), CategoricalSpace(name='shbckfrkow', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='ywqobigbvi', lower_bound=-10000000.0, upper_bound=10000000.1, type='float')])
# DoE(input_space=[ContinuousSpace(name='ymbycigvum', lower_bound=-10000000.0, upper_bound=0.10000000000000023, type='float'), DiscreteSpace(name='dulyoeaevm', lower_bound=-23146, upper_bound=28378, type='int'), ContinuousSpace(name='iblnsxupcc', lower_bound=0.0, upper_bound=inf, type='float'), DiscreteSpace(name='zrvsycgzlo', lower_bound=-19555, upper_bound=30320, type='int'), DiscreteSpace(name='prljwsiolk', lower_bound=-73, upper_bound=769, type='int')], output_space=[CategoricalSpace(name='okbhjixgar', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='rkaytpvnmb', lower_bound=0.0, upper_bound=0.1, type='float'), CategoricalSpace(name='shbckfrkow', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='ywqobigbvi', lower_bound=-10000000.0, upper_bound=10000000.1, type='float')])
# DoE(input_space=[ContinuousSpace(name='ymbycicvum', lower_bound=-10000000.0, upper_bound=0.10000000000000023, type='float'), DiscreteSpace(name='dulyoeaevm', lower_bound=-23146, upper_bound=28378, type='int'), ContinuousSpace(name='iblnsxupcc', lower_bound=0.0, upper_bound=inf, type='float'), DiscreteSpace(name='zrvsycgzlo', lower_bound=-19555, upper_bound=30320, type='int'), DiscreteSpace(name='prljwsiolk', lower_bound=-73, upper_bound=769, type='int')], output_space=[CategoricalSpace(name='okbhjixgar', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='rkaytpvnmb', lower_bound=0.0, upper_bound=0.1, type='float'), CategoricalSpace(name='shbckfrkow', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='ywqobigbvi', lower_bound=-10000000.0, upper_bound=10000000.1, type='float')])
# DoE(input_space=[ContinuousSpace(name='iitexotdha', lower_bound=-2.220446049250313e-16, upper_bound=0.1, type='float'), DiscreteSpace(name='fjzlaxbsin', lower_bound=-13242, upper_bound=29730, type='int'), ContinuousSpace(name='aqzrogugxq', lower_bound=-6.103515625e-05, upper_bound=1.9860797416923264e+16, type='float'), DiscreteSpace(name='mboedzdtua', lower_bound=-401485091, upper_bound=40, type='int'), DiscreteSpace(name='vrhwryopal', lower_bound=-3173123275919114356, upper_bound=68, type='int')], output_space=[CategoricalSpace(name='rxjvpnoflv', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='ezqwpvkkxh', lower_bound=0.0, upper_bound=0.1, type='float'), CategoricalSpace(name='qlkfpunpvz', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='eqrisqwvjs', lower_bound=-2.4503084177589584e+16, upper_bound=1.09999, type='float'), ContinuousSpace(name='qiqrelmjom', lower_bound=0.0, upper_bound=1.4646721500347928e+198, type='float')])
# ...
# DoE(input_space=[ContinuousSpace(name='bewxzkmjbm', lower_bound=0.0, upper_bound=0.10000000000000023, type='float'), DiscreteSpace(name='aaaabubyhw', lower_bound=-9, upper_bound=257, type='int'), ContinuousSpace(name='lfadcaznzu', lower_bound=-3.402823466e+38, upper_bound=919041.1, type='float'), DiscreteSpace(name='irmrrsaehn', lower_bound=-5, upper_bound=385, type='int'), DiscreteSpace(name='nigdasdqsr', lower_bound=-3464, upper_bound=180848225555266525, type='int'), CategoricalSpace(name='efaymcvmgn', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='latqgjnpyp', lower_bound=-6493721028658949.0, upper_bound=276.1, type='float'), CategoricalSpace(name='bjaaaaaaaa', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='mdijxjzjnz', lower_bound=0.0, upper_bound=9007199254740992.0, type='float'), ContinuousSpace(name='dbbbpdaaaa', lower_bound=0.0, upper_bound=1.2000000000000002, type='float'), ContinuousSpace(name='fvabiaaaaa', lower_bound=0.0, upper_bound=3664680862351628.0, type='float'), CategoricalSpace(name='bbiaaaaaaa', categories=['test1', 'test2'], type='category')], output_space=[DiscreteSpace(name='rdbhqaaaaa', lower_bound=-1423, upper_bound=2823, type='int'), CategoricalSpace(name='lnnjgjcqvo', categories=['test1', 'test2'], type='category')])
# DoE(input_space=[ContinuousSpace(name='bewxzkmjbm', lower_bound=0.0, upper_bound=0.10000000000000023, type='float'), DiscreteSpace(name='aaaabubyhw', lower_bound=-9, upper_bound=257, type='int'), ContinuousSpace(name='lfadcaznzu', lower_bound=-3.402823466e+38, upper_bound=919041.1, type='float'), DiscreteSpace(name='irmrrsaehn', lower_bound=-5, upper_bound=385, type='int'), DiscreteSpace(name='nigdasdqsr', lower_bound=-3464, upper_bound=180848225555266525, type='int'), CategoricalSpace(name='efaymcvmgn', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='latqgjnpyp', lower_bound=-6493721028658949.0, upper_bound=276.1, type='float'), CategoricalSpace(name='bjaaaaaaaa', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='mdijxjzjnz', lower_bound=0.0, upper_bound=9007199254740992.0, type='float'), ContinuousSpace(name='dbbbpdaaaa', lower_bound=0.0, upper_bound=1.2000000000000002, type='float'), ContinuousSpace(name='fvabiaaaaa', lower_bound=0.0, upper_bound=3664680862351628.0, type='float'), CategoricalSpace(name='bbiaaaaaaa', categories=['test1', 'test2'], type='category')], output_space=[DiscreteSpace(name='rdbhqaaaaa', lower_bound=-1423, upper_bound=2823, type='int'), CategoricalSpace(name='lnnjgjcqvo', categories=['test1', 'test2'], type='category'), CategoricalSpace(name='jkmcvlfgdm', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='mzveqghyew', lower_bound=-1.1485186602637672e-88, upper_bound=1.7976931348623157e+308, type='float'), DiscreteSpace(name='epfceduhoa', lower_bound=-4014, upper_bound=17013, type='int'), DiscreteSpace(name='aztwvtnltx', lower_bound=-16537, upper_bound=3576, type='int'), DiscreteSpace(name='nwkcrokjcd', lower_bound=-2797527313368618672, upper_bound=4370, type='int'), DiscreteSpace(name='cfhyvmeelf', lower_bound=-5861, upper_bound=87, type='int'), ContinuousSpace(name='fgbftcxeoz', lower_bound=0.0, upper_bound=0.1, type='float'), DiscreteSpace(name='krzfpxkqlo', lower_bound=-16089, upper_bound=9999, type='int'), ContinuousSpace(name='gxnqxrfkxn', lower_bound=0.0, upper_bound=0.1, type='float'), ContinuousSpace(name='pipnhlhlnj', lower_bound=-3.038055395238138e-188, upper_bound=inf, type='float')])
# DoE(input_space=[ContinuousSpace(name='lmstspigwd', lower_bound=-0.5, upper_bound=0.1, type='float'), DiscreteSpace(name='xombaijqol', lower_bound=-12622, upper_bound=6899, type='int'), ContinuousSpace(name='lnwjvqtopi', lower_bound=0.0, upper_bound=0.1, type='float'), DiscreteSpace(name='lfdndtkaff', lower_bound=-2211, upper_bound=1392, type='int'), DiscreteSpace(name='toafhtvibq', lower_bound=-7047, upper_bound=5612270207179668248, type='int'), CategoricalSpace(name='sqefirfuwy', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='vvvhpbinvq', lower_bound=0.0, upper_bound=1.09999, type='float'), CategoricalSpace(name='jjrocozdep', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='nfsenkepvu', lower_bound=0.0, upper_bound=inf, type='float'), ContinuousSpace(name='mgrxphxpjc', lower_bound=0.0, upper_bound=1.747208658010037e+97, type='float')], output_space=[ContinuousSpace(name='ugvnqyxohg', lower_bound=0.0, upper_bound=0.1, type='float'), CategoricalSpace(name='kyyuqpookk', categories=['test1', 'test2'], type='category'), DiscreteSpace(name='heisrwjpiz', lower_bound=-20391, upper_bound=88, type='int'), CategoricalSpace(name='qwejzrozxl', categories=['test1', 'test2'], type='category'), CategoricalSpace(name='cwtnprpgqu', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='wnkhwezszd', lower_bound=-1e-05, upper_bound=2.10001, type='float'), DiscreteSpace(name='fvocxagwri', lower_bound=-22812, upper_bound=125, type='int')])
# DoE(input_space=[ContinuousSpace(name='vfieuuqdtt', lower_bound=-inf, upper_bound=0.10000047012617849, type='float'), DiscreteSpace(name='sfpfvnnrnj', lower_bound=-1541358809, upper_bound=1628018261, type='int'), ContinuousSpace(name='fhwjqunarq', lower_bound=0.0, upper_bound=0.1, type='float'), DiscreteSpace(name='tioedbuqle', lower_bound=-102664443, upper_bound=47, type='int'), DiscreteSpace(name='fichgcuare', lower_bound=-28827, upper_bound=16090, type='int')], output_space=[CategoricalSpace(name='nkwqumjleb', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='kizdywumca', lower_bound=-3.402823466e+38, upper_bound=inf, type='float'), CategoricalSpace(name='irxjlqrvbv', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='efijiykskm', lower_bound=0.0, upper_bound=0.1, type='float'), ContinuousSpace(name='urmbswjnvs', lower_bound=-1.1125369292536007e-308, upper_bound=inf, type='float'), ContinuousSpace(name='pikwltkdvi', lower_bound=0.0, upper_bound=0.43333333333333335, type='float'), CategoricalSpace(name='lfxmzuvkyu', categories=['test1', 'test2'], type='category'), DiscreteSpace(name='fnfjldotmw', lower_bound=-2726, upper_bound=7673552456949451917, type='int'), CategoricalSpace(name='fzvrnbbiui', categories=['test1', 'test2'], type='category'), CategoricalSpace(name='dztiulwdxt', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='tmxfhauhyi', lower_bound=0.0, upper_bound=1.7976931348623157e+308, type='float'), DiscreteSpace(name='nyxyrvkugx', lower_bound=-79, upper_bound=8567, type='int'), DiscreteSpace(name='nylslhwiby', lower_bound=-28, upper_bound=549, type='int'), DiscreteSpace(name='vzarwbrkhx', lower_bound=-3289, upper_bound=12939, type='int')])
# DoE(input_space=[ContinuousSpace(name='jnftjawmbu', lower_bound=0.0, upper_bound=1.8118096357898104e+16, type='float'), DiscreteSpace(name='lknnaeklrl', lower_bound=-1727, upper_bound=5918, type='int'), ContinuousSpace(name='wsiikajljd', lower_bound=0.0, upper_bound=10000000.1, type='float'), DiscreteSpace(name='rmvxciqfyp', lower_bound=-8331, upper_bound=5971650202537171776, type='int'), DiscreteSpace(name='szkkmudqqc', lower_bound=-4716188084986012553, upper_bound=9, type='int'), CategoricalSpace(name='mrfrmiauyp', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='iclkysyais', lower_bound=0.0, upper_bound=2.10001, type='float'), CategoricalSpace(name='iuqaauovob', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='begwklmhot', lower_bound=0.0, upper_bound=0.10001, type='float'), ContinuousSpace(name='btkdzfuwte', lower_bound=-2.2250738585e-313, upper_bound=2.0, type='float'), ContinuousSpace(name='cplgvruwyi', lower_bound=-9007199254740992.0, upper_bound=inf, type='float'), CategoricalSpace(name='swuujppxpe', categories=['test1', 'test2'], type='category'), DiscreteSpace(name='ohgdkqdbba', lower_bound=-8555, upper_bound=26901, type='int')], output_space=[CategoricalSpace(name='kijhwhxrxx', categories=['test1', 'test2'], type='category')])
# DoE(input_space=[ContinuousSpace(name='jnftjawmbu', lower_bound=-2.2250738585e-313, upper_bound=1.8118096357898104e+16, type='float'), DiscreteSpace(name='lknnaeklrl', lower_bound=-1727, upper_bound=5918, type='int'), ContinuousSpace(name='wsiikajljd', lower_bound=0.0, upper_bound=10000000.1, type='float'), DiscreteSpace(name='rmvxciqfyp', lower_bound=-8331, upper_bound=5971650202537171776, type='int'), DiscreteSpace(name='szkkmudqqc', lower_bound=-4716188084986012553, upper_bound=9, type='int'), CategoricalSpace(name='mrfrmiauyp', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='iclkysyais', lower_bound=0.0, upper_bound=2.10001, type='float'), CategoricalSpace(name='iuqaauovob', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='begwklmhot', lower_bound=0.0, upper_bound=0.10001, type='float'), ContinuousSpace(name='btkdzfuwte', lower_bound=-2.2250738585e-313, upper_bound=2.0, type='float'), ContinuousSpace(name='cplgvruwyi', lower_bound=-9007199254740992.0, upper_bound=inf, type='float'), CategoricalSpace(name='swuujppxpe', categories=['test1', 'test2'], type='category'), DiscreteSpace(name='ohgdkqdbba', lower_bound=-8555, upper_bound=26901, type='int')], output_space=[CategoricalSpace(name='kijhwhxrxx', categories=['test1', 'test2'], type='category')])
# DoE(input_space=[ContinuousSpace(name='razmwtsfin', lower_bound=0.0, upper_bound=1.09999, type='float'), DiscreteSpace(name='nylfhpnrvi', lower_bound=-91, upper_bound=23721, type='int'), ContinuousSpace(name='aveoyhsvri', lower_bound=-2.220446049250313e-16, upper_bound=7092664115311043.0, type='float'), DiscreteSpace(name='uaepanugvg', lower_bound=-3477, upper_bound=90, type='int'), DiscreteSpace(name='ryrkdwkfkg', lower_bound=-6, upper_bound=1257, type='int')], output_space=[CategoricalSpace(name='bfonihwcpf', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='lrnhqzemxu', lower_bound=-inf, upper_bound=0.1, type='float'), CategoricalSpace(name='ukonxnjmwg', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='ycdtltyesk', lower_bound=0.0, upper_bound=inf, type='float'), ContinuousSpace(name='ayglzqcjom', lower_bound=0.0, upper_bound=2.10001, type='float'), ContinuousSpace(name='asggnzlxah', lower_bound=0.0, upper_bound=inf, type='float'), CategoricalSpace(name='zqubdqjeoa', categories=['test1', 'test2'], type='category'), DiscreteSpace(name='fwdntpuqqd', lower_bound=-3798, upper_bound=23166, type='int'), CategoricalSpace(name='mipcmpivjp', categories=['test1', 'test2'], type='category'), CategoricalSpace(name='agxrgghoen', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='vlrlfgarit', lower_bound=-1.175494351e-38, upper_bound=0.43333333333333335, type='float'), DiscreteSpace(name='feneabiltf', lower_bound=-19778, upper_bound=831146450, type='int'), DiscreteSpace(name='erfefvsvjl', lower_bound=-5847, upper_bound=77, type='int'), DiscreteSpace(name='fdxzpfbwyi', lower_bound=-20787, upper_bound=88, type='int'), DiscreteSpace(name='lkadpizmbk', lower_bound=-26959, upper_bound=32744, type='int'), ContinuousSpace(name='thuflamhyu', lower_bound=-10000000.0, upper_bound=0.1, type='float')])
# DoE(input_space=[ContinuousSpace(name='lphkwwdfjl', lower_bound=-2.2250738585072014e-308, upper_bound=0.1, type='float'), DiscreteSpace(name='jmugrlupiw', lower_bound=-117, upper_bound=7, type='int'), ContinuousSpace(name='rdlplrpase', lower_bound=-2.654492616657033e+16, upper_bound=0.1, type='float'), DiscreteSpace(name='veebhbczja', lower_bound=-60, upper_bound=39, type='int'), DiscreteSpace(name='cbxcwgmjza', lower_bound=-22033, upper_bound=14718, type='int'), CategoricalSpace(name='gmmpckjhdw', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='wjvkldfjum', lower_bound=-2.00001, upper_bound=1.09999, type='float'), CategoricalSpace(name='vniwpvucdx', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='njlwjjnraq', lower_bound=0.0, upper_bound=inf, type='float'), ContinuousSpace(name='wjlinjkklp', lower_bound=0.0, upper_bound=1.9255195069016024e+16, type='float'), ContinuousSpace(name='egdglxgouu', lower_bound=-inf, upper_bound=0.10000000000000023, type='float'), CategoricalSpace(name='gcjavqgzam', categories=['test1', 'test2'], type='category')], output_space=[DiscreteSpace(name='xonlzbpikz', lower_bound=-26407, upper_bound=13632, type='int'), CategoricalSpace(name='fvfwhqspto', categories=['test1', 'test2'], type='category'), CategoricalSpace(name='ixclkrxrto', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='ovwkkisopu', lower_bound=0.0, upper_bound=1.17457556405015e+16, type='float'), DiscreteSpace(name='remchvabeq', lower_bound=-2077556114, upper_bound=1834, type='int'), DiscreteSpace(name='yignclahzp', lower_bound=-37, upper_bound=24903, type='int'), DiscreteSpace(name='fizuipgmxy', lower_bound=-3015312593427578863, upper_bound=32105, type='int'), DiscreteSpace(name='kislhmhcff', lower_bound=-65, upper_bound=49, type='int'), ContinuousSpace(name='oygkwukvjx', lower_bound=-2.225073858507e-311, upper_bound=inf, type='float')])
# DoE(input_space=[ContinuousSpace(name='xuukxamdad', lower_bound=-5.732916064005209e+16, upper_bound=0.10000005960464478, type='float'), DiscreteSpace(name='gbtplknzrx', lower_bound=-25887, upper_bound=109, type='int'), ContinuousSpace(name='dvasrarbtg', lower_bound=0.0, upper_bound=0.1, type='float'), DiscreteSpace(name='wvxbqsxwiq', lower_bound=-12871, upper_bound=1853376124, type='int'), DiscreteSpace(name='ycesnncqto', lower_bound=-732757642, upper_bound=2994401406280918320, type='int'), CategoricalSpace(name='gnzqokoyen', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='uappxhumzt', lower_bound=0.0, upper_bound=1.6842482932171604e+16, type='float'), CategoricalSpace(name='mdpemijnip', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='wyitdzovrl', lower_bound=-2.2250738585e-313, upper_bound=9007199254740992.0, type='float'), ContinuousSpace(name='zhzjyqrwcg', lower_bound=0.0, upper_bound=0.1, type='float'), ContinuousSpace(name='ctanbrxorg', lower_bound=0.0, upper_bound=0.1, type='float'), CategoricalSpace(name='iaxcwwnnku', categories=['test1', 'test2'], type='category'), DiscreteSpace(name='snpplpgypk', lower_bound=-44, upper_bound=25699, type='int'), CategoricalSpace(name='pwyxwgyejs', categories=['test1', 'test2'], type='category'), CategoricalSpace(name='hxpsiswnzj', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='mxdgdjcxxh', lower_bound=-5e-324, upper_bound=9007199254740992.0, type='float')], output_space=[DiscreteSpace(name='ouczdhezzt', lower_bound=-3077, upper_bound=27720, type='int'), DiscreteSpace(name='mlunqiurye', lower_bound=-1447846510085130296, upper_bound=48, type='int'), DiscreteSpace(name='flbsvybdhw', lower_bound=-86, upper_bound=27702, type='int'), DiscreteSpace(name='dcotpioypq', lower_bound=-59, upper_bound=24, type='int'), ContinuousSpace(name='fbazbidgxs', lower_bound=0.0, upper_bound=2.5369582684551544e+16, type='float'), DiscreteSpace(name='bebepoforq', lower_bound=-15, upper_bound=6419240880548237800, type='int'), ContinuousSpace(name='pmoecfhqgv', lower_bound=0.0, upper_bound=0.1, type='float'), ContinuousSpace(name='gfdfckwtyx', lower_bound=-4.817267563486978e+16, upper_bound=0.1, type='float'), DiscreteSpace(name='yjzahzeugu', lower_bound=-220705835, upper_bound=14317, type='int'), CategoricalSpace(name='riaqdajpek', categories=['test1', 'test2'], type='category'), ContinuousSpace(name='adoyvmlzqn', lower_bound=0.0, upper_bound=1.7976931348623157e+308, type='float'), CategoricalSpace(name='mezdyrdjkr', categories=['test1', 'test2'], type='category')])
