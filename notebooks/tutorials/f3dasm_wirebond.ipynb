# %% [markdown]
# ### Wirebond data visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('../resources/sweep_MeshSize=1.55_20221227_1506.csv')
df_clean = df.dropna()

fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter(df_clean['WThk'], df_clean['FL'], df_clean['MaxEPS'])
