# %%
from f3dasm.src.designofexperiments import DoE
from f3dasm.src.space import ContinuousSpace, DiscreteSpace
from f3dasm.sampling.latinhypercube import LatinHypercube
from f3dasm.sampling.randomuniform import RandomUniform
from f3dasm.sampling.sobolsequence import SobolSequencing
import matplotlib.pyplot as plt

# %%
x1 = ContinuousSpace('x1', lower_bound=0.0, upper_bound=100.0)
x2 = ContinuousSpace('x2', lower_bound=0.0, upper_bound=4.0)
x3 = DiscreteSpace('x3', lower_bound=2, upper_bound=4)

# %%
space = [x1, x2, x3]
design = DoE(space=space)

# %%
design
# Out:
# DoE(space=[ContinuousSpace(name='x1', lower_bound=0.0, upper_bound=100.0), ContinuousSpace(name='x2', lower_bound=0.0, upper_bound=4.0), DiscreteSpace(name='x3', lower_bound=2, upper_bound=4)], constraints=[])

# %%
lhs = LatinHypercube(doe=design)
ran = RandomUniform(doe=design)
sob = SobolSequencing(doe=design)

# %%
N = 1000
samples_lhs = lhs.sample(numsamples=N, doe=design)
samples_ran = ran.sample(numsamples=N, doe=design)
samples_sob = sob.sample(numsamples=N, doe=design)


plt.scatter(samples_lhs[:,0],samples_lhs[:,1],s=2)
plt.scatter(samples_ran[:,0],samples_ran[:,1], color='red',s=2)
plt.scatter(samples_sob[:,0],samples_sob[:,1], color='green',s=2)

# %%
samples[:,0]

# %%
s[0,:]
